# %% [markdown]
# # 自然语言风控规则解析探索
#
# 本 Notebook 用于交互式实验：
# - 测试不同提示词版本对解析结果的影响
# - 可视化置信度分布、字段级准确率等指标
# - 记录论文中的关键实验截图
#
# 后续可以在这里：
# - 调用 `QwenRuleLLMParser` 解析一批样本
# - 使用 `evaluation.metrics` 计算各类指标
# - 用 matplotlib / seaborn 画图
